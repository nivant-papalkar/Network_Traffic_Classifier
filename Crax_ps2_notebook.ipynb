# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('/kaggle/input/firsttry-train/training_set.csv')
test = pd.read_csv('/kaggle/input/firsttry-train/test.csv')

# %%
print(train.info())
print(train.head())

print(train.isnull().sum())
print(train["traffic_label"].value_counts(normalize=True) * 100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 44 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Id                 175341 non-null  int64
#  1   time_span          175341 non-null  float64
#  2   proto_label        175341 non-null  object
#  3   svc_type           175341 non-null  object
#  4   conn_state         175341 non-null  object
#  5   src_pkts           175341 non-null  int64
#  6   dst_pkts           175341 non-null  int64
#  7   src_bytes          175341 non-null  int64
#  8   dst_bytes          175341 non-null  int64
#  9   conn_rate          175341 non-null  float64
#  10  src_ttl            175341 non-null  int64
#  11  dst_ttl            175341 non-null  int64
#  12  src_load           175341 non-null  float64
#  13  dst_load           175341 non-null  float64
#  14  src_loss           175341 non-null  int64
#  15  dst_loss           175341 non-null  int64
#  16  src_intpkt         175341 non-null  float64
#  17  dst_intpkt         175341 non-null  float64
#  18  src_jitter         175341 non-null  float64
#  19  dst_jitter         175341 non-null  float64
#  20  src_win            175341 non-null  int64
#  21  src_tcp_base       175341 non-null  int64
#  22  dst_tcp_base       175341 non-null  int64
#  23  dst_win            175341 non-null  int64
#  24  tcp_rtt            175341 non-null  float64
#  25  tcp_synack         175341 non-null  float64
#  26  tcp_ackdata        175341 non-null  float64
#  27  src_mean           175341 non-null  int64
#  28  dst_mean           175341 non-null  int64
#  29  trans_level        175341 non-null  int64
#  30  resp_body_len      175341 non-null  int64
#  31  ct_srv_srcX        175341 non-null  int64
#  32  ct_st_ttlX         175341 non-null  int64
#  33  ct_dst_ltmX        175341 non-null  int64
#  34  ct_src_dport_ltmX  175341 non-null  int64
#  35  ct_dst_sport_ltmX  175341 non-null  int64
#  36  ct_dst_src_ltmX    175341 non-null  int64
#  37  ftp_login_flag     175341 non-null  int64
#  38  ftp_cmd_count      175341 non-null  int64
#  39  http_mthd_count    175341 non-null  int64
#  40  ct_src_ltmX        175341 non-null  int64
#  41  ct_srv_dstX        175341 non-null  int64
#  42  sm_ips_ports_flag  175341 non-null  int64
#  43  traffic_label      175341 non-null  object
# dtypes: float64(11), int64(29), object(4)
# memory usage: 58.9+ MB
# None
#    Id  time_span proto_label svc_type conn_state  src_pkts  dst_pkts  \
# 0   1   0.121478         tcp        -        FIN         6         4
# 1   2   0.649902         tcp        -        FIN        14        38
# 2   3   1.623129         tcp        -        FIN         8        16
# 3   4   1.681642         tcp      ftp        FIN        12        12
# 4   5   0.449454         tcp        -        FIN        10         6
#
#    src_bytes  dst_bytes  conn_rate  ...  ct_src_dport_ltmX  ct_dst_sport_ltmX  \
# 0        258        172  74.087490  ...                  1                  1
# 1        734      42014  78.473372  ...                  1                  1
# 2        364      13186  14.170161  ...                  1                  1
# 3        628        770  13.677108  ...                  1                  1
# 4        534        268  33.373826  ...                  2                  1
#
#    ct_dst_src_ltmX  ftp_login_flag  ftp_cmd_count  http_mthd_count  \
# 0                1               0              0                0
# 1                2               0              0                0
# 2                3               0              0                0
# 3                3               1              1                0
# 4               40               0              0                0
#
#    ct_src_ltmX  ct_srv_dstX  sm_ips_ports_flag  traffic_label
# 0            1            1                  0         Normal
# 1            1            6                  0         Normal
# 2            2            6                  0         Normal
# 3            2            1                  0         Normal
# 4            2           39                  0         Normal
#
# [5 rows x 44 columns]
# Id                   0
# time_span            0
# proto_label          0
# svc_type             0
# conn_state           0
# src_pkts             0
# dst_pkts             0
# src_bytes            0
# dst_bytes            0
# conn_rate            0
# src_ttl              0
# dst_ttl              0
# src_load             0
# dst_load             0
# src_loss             0
# dst_loss             0
# src_intpkt           0
# dst_intpkt           0
# src_jitter           0
# dst_jitter           0
# src_win              0
# src_tcp_base         0
# dst_tcp_base         0
# dst_win              0
# tcp_rtt              0
# tcp_synack           0
# tcp_ackdata          0
# src_mean             0
# dst_mean             0
# trans_level          0
# resp_body_len        0
# ct_srv_srcX          0
# ct_st_ttlX           0
# ct_dst_ltmX          0
# ct_src_dport_ltmX    0
# ct_dst_sport_ltmX    0
# ct_dst_src_ltmX      0
# ftp_login_flag       0
# ftp_cmd_count        0
# http_mthd_count      0
# ct_src_ltmX          0
# ct_srv_dstX          0
# sm_ips_ports_flag    0
# traffic_label        0
# dtype: int64
# traffic_label
# Normal            31.937767
# Generic           22.812691
# Exploits          19.044605
# Fuzzers           10.370649
# DoS                6.994371
# Reconnaissance     5.983198
# Analysis           1.140635
# Backdoor           0.995774
# Shellcode          0.646169
# Worms              0.074141
# Name: proportion, dtype: float64

# %%
test_ids = test["Id"].copy()
train.drop(columns=['Id'], inplace=True)
test.drop(columns=['Id'], inplace=True)
y = train['traffic_label']
X = train.drop(columns=['traffic_label'])

# %%
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['proto_label', 'svc_type', 'conn_state']

for col in categorical_cols:
    le = LabelEncoder()

    X[col] = le.fit_transform(X[col])
    test[col] = test[col].map(lambda x: le.transform([x])[0] if x in le.classes_ else -1)

    X[col] = X[col].astype(int)
    test[col] = test[col].astype(int)

print("Updated Data Types:\n", X.dtypes)
# Out:
# Updated Data Types:
#  time_span            float64
# proto_label            int64
# svc_type               int64
# conn_state             int64
# src_pkts               int64
# dst_pkts               int64
# src_bytes              int64
# dst_bytes              int64
# conn_rate            float64
# src_ttl                int64
# dst_ttl                int64
# src_load             float64
# dst_load             float64
# src_loss               int64
# dst_loss               int64
# src_intpkt           float64
# dst_intpkt           float64
# src_jitter           float64
# dst_jitter           float64
# src_win                int64
# src_tcp_base           int64
# dst_tcp_base           int64
# dst_win                int64
# tcp_rtt              float64
# tcp_synack           float64
# tcp_ackdata          float64
# src_mean               int64
# dst_mean               int64
# trans_level            int64
# resp_body_len          int64
# ct_srv_srcX            int64
# ct_st_ttlX             int64
# ct_dst_ltmX            int64
# ct_src_dport_ltmX      int64
# ct_dst_sport_ltmX      int64
# ct_dst_src_ltmX        int64
# ftp_login_flag         int64
# ftp_cmd_count          int64
# http_mthd_count        int64
# ct_src_ltmX            int64
# ct_srv_dstX            int64
# sm_ips_ports_flag      int64
# dtype: object

# %%
print(X.info())
print(test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 42 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   time_span          175341 non-null  float64
#  1   proto_label        175341 non-null  int64
#  2   svc_type           175341 non-null  int64
#  3   conn_state         175341 non-null  int64
#  4   src_pkts           175341 non-null  int64
#  5   dst_pkts           175341 non-null  int64
#  6   src_bytes          175341 non-null  int64
#  7   dst_bytes          175341 non-null  int64
#  8   conn_rate          175341 non-null  float64
#  9   src_ttl            175341 non-null  int64
#  10  dst_ttl            175341 non-null  int64
#  11  src_load           175341 non-null  float64
#  12  dst_load           175341 non-null  float64
#  13  src_loss           175341 non-null  int64
#  14  dst_loss           175341 non-null  int64
#  15  src_intpkt         175341 non-null  float64
#  16  dst_intpkt         175341 non-null  float64
#  17  src_jitter         175341 non-null  float64
#  18  dst_jitter         175341 non-null  float64
#  19  src_win            175341 non-null  int64
#  20  src_tcp_base       175341 non-null  int64
#  21  dst_tcp_base       175341 non-null  int64
#  22  dst_win            175341 non-null  int64
#  23  tcp_rtt            175341 non-null  float64
#  24  tcp_synack         175341 non-null  float64
#  25  tcp_ackdata        175341 non-null  float64
#  26  src_mean           175341 non-null  int64
#  27  dst_mean           175341 non-null  int64
#  28  trans_level        175341 non-null  int64
#  29  resp_body_len      175341 non-null  int64
#  30  ct_srv_srcX        175341 non-null  int64
#  31  ct_st_ttlX         175341 non-null  int64
#  32  ct_dst_ltmX        175341 non-null  int64
#  33  ct_src_dport_ltmX  175341 non-null  int64
#  34  ct_dst_sport_ltmX  175341 non-null  int64
#  35  ct_dst_src_ltmX    175341 non-null  int64
#  36  ftp_login_flag     175341 non-null  int64
#  37  ftp_cmd_count      175341 non-null  int64
#  38  http_mthd_count    175341 non-null  int64
#  39  ct_src_ltmX        175341 non-null  int64
#  40  ct_srv_dstX        175341 non-null  int64
#  41  sm_ips_ports_flag  175341 non-null  int64
# dtypes: float64(11), int64(31)
# memory usage: 56.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82332 entries, 0 to 82331
# Data columns (total 42 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   time_span          82332 non-null  float64
#  1   proto_label        82332 non-null  int64
#  2   svc_type           82332 non-null  int64
#  3   conn_state         82332 non-null  int64
#  4   src_pkts           82332 non-null  int64
#  5   dst_pkts           82332 non-null  int64
#  6   src_bytes          82332 non-null  int64
#  7   dst_bytes          82332 non-null  int64
#  8   conn_rate          82332 non-null  float64
#  9   src_ttl            82332 non-null  int64
#  10  dst_ttl            82332 non-null  int64
#  11  src_load           82332 non-null  float64
#  12  dst_load           82332 non-null  float64
#  13  src_loss           82332 non-null  int64
#  14  dst_loss           82332 non-null  int64
#  15  src_intpkt         82332 non-null  float64
#  16  dst_intpkt         82332 non-null  float64
#  17  src_jitter         82332 non-null  float64
#  18  dst_jitter         82332 non-null  float64
#  19  src_win            82332 non-null  int64
#  20  src_tcp_base       82332 non-null  int64
#  21  dst_tcp_base       82332 non-null  int64
#  22  dst_win            82332 non-null  int64
#  23  tcp_rtt            82332 non-null  float64
#  24  tcp_synack         82332 non-null  float64
#  25  tcp_ackdata        82332 non-null  float64
#  26  src_mean           82332 non-null  int64
#  27  dst_mean           82332 non-null  int64
#  28  trans_level        82332 non-null  int64
#  29  resp_body_len      82332 non-null  int64
#  30  ct_srv_srcX        82332 non-null  int64
#  31  ct_st_ttlX         82332 non-null  int64
#  32  ct_dst_ltmX        82332 non-null  int64
#  33  ct_src_dport_ltmX  82332 non-null  int64
#  34  ct_dst_sport_ltmX  82332 non-null  int64
#  35  ct_dst_src_ltmX    82332 non-null  int64
#  36  ftp_login_flag     82332 non-null  int64
#  37  ftp_cmd_count      82332 non-null  int64
#  38  http_mthd_count    82332 non-null  int64
#  39  ct_src_ltmX        82332 non-null  int64
#  40  ct_srv_dstX        82332 non-null  int64
#  41  sm_ips_ports_flag  82332 non-null  int64
# dtypes: float64(11), int64(31)
# memory usage: 26.4 MB
# None

# %%
from sklearn.preprocessing import LabelEncoder

le_traffic = LabelEncoder()
y = le_traffic.fit_transform(train["traffic_label"])

print("Label Encoding Mapping:")
print(dict(zip(le_traffic.classes_, le_traffic.transform(le_traffic.classes_))))

print("Before Encoding:", train["traffic_label"].unique()[:10])
print("After Encoding:", y[:10])
# Out:
# Label Encoding Mapping:
# {'Analysis': 0, 'Backdoor': 1, 'DoS': 2, 'Exploits': 3, 'Fuzzers': 4, 'Generic': 5, 'Normal': 6, 'Reconnaissance': 7, 'Shellcode': 8, 'Worms': 9}
# Before Encoding: ['Normal' 'Backdoor' 'Analysis' 'Fuzzers' 'Shellcode' 'Reconnaissance'
#  'Exploits' 'DoS' 'Worms' 'Generic']
# After Encoding: [6 6 6 6 6 6 6 6 6 6]

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.1, stratify=y, random_state=42
)

# %%
print("Remaining object columns in X_train:", X_train.select_dtypes(include=['object']).columns.tolist())
print("Remaining object columns in X_val:", X_val.select_dtypes(include=['object']).columns.tolist())
# Out:
# Remaining object columns in X_train: []
# Remaining object columns in X_val: []

# %%
from sklearn.ensemble import StackingClassifier, RandomForestClassifier, ExtraTreesClassifier
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
#best 79.93 aaya
base_models = [
    ('xgb', XGBClassifier(
        objective='multi:softprob',
        max_depth=6,
        learning_rate=0.05,
        n_estimators=500,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=42
    )),
 ('lgbm', LGBMClassifier(
        objective='multiclass',
        random_state=42
    )),
    ('extratrees', ExtraTreesClassifier(
        n_estimators=100,
        random_state=42
    )),
    ('mlp', MLPClassifier(
        hidden_layer_sizes=(64, 32),
        alpha=0.01,
        learning_rate_init=0.001,
        max_iter=500,
        random_state=42
    )),
    ('hgb', HistGradientBoostingClassifier(
        learning_rate=0.03,
        max_iter=300,
        max_depth=6,
        random_state=42
    )),
    ('catboost', CatBoostClassifier(
        loss_function='MultiClass',
        random_state=42,
        verbose=0
    ))
]

meta_model = LogisticRegression(max_iter=1000, multi_class='ovr')
stack = StackingClassifier(
    estimators=base_models,
    final_estimator=meta_model,
    cv=2
)

# %%
stack.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018948 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6143
# [LightGBM] [Info] Number of data points in the train set: 157806, number of used features: 42
# [LightGBM] [Info] Start training from score -4.473580
# [LightGBM] [Info] Start training from score -4.609654
# [LightGBM] [Info] Start training from score -2.660023
# [LightGBM] [Info] Start training from score -1.658404
# [LightGBM] [Info] Start training from score -2.266222
# [LightGBM] [Info] Start training from score -1.477847
# [LightGBM] [Info] Start training from score -1.141375
# [LightGBM] [Info] Start training from score -2.816199
# [LightGBM] [Info] Start training from score -5.041564
# [LightGBM] [Info] Start training from score -7.206948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005879 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6053
# [LightGBM] [Info] Number of data points in the train set: 78903, number of used features: 42
# [LightGBM] [Info] Start training from score -4.473580
# [LightGBM] [Info] Start training from score -4.610291
# [LightGBM] [Info] Start training from score -2.660023
# [LightGBM] [Info] Start training from score -1.658437
# [LightGBM] [Info] Start training from score -2.266160
# [LightGBM] [Info] Start training from score -1.477847
# [LightGBM] [Info] Start training from score -1.141375
# [LightGBM] [Info] Start training from score -2.816199
# [LightGBM] [Info] Start training from score -5.041564
# [LightGBM] [Info] Start training from score -7.198437
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6059
# [LightGBM] [Info] Number of data points in the train set: 78903, number of used features: 42
# [LightGBM] [Info] Start training from score -4.473580
# [LightGBM] [Info] Start training from score -4.609018
# [LightGBM] [Info] Start training from score -2.660023
# [LightGBM] [Info] Start training from score -1.658371
# [LightGBM] [Info] Start training from score -2.266283
# [LightGBM] [Info] Start training from score -1.477847
# [LightGBM] [Info] Start training from score -1.141375
# [LightGBM] [Info] Start training from score -2.816199
# [LightGBM] [Info] Start training from score -5.041564
# [LightGBM] [Info] Start training from score -7.215532
# StackingClassifier(cv=2,
#                    estimators=[('xgb',
#                                 XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.8, device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learn...
#                                 ExtraTreesClassifier(random_state=42)),
#                                ('mlp',
#                                 MLPClassifier(alpha=0.01,
#                                               hidden_layer_sizes=(64, 32),
#                                               max_iter=500, random_state=42)),
#                                ('hgb',
#                                 HistGradientBoostingClassifier(learning_rate=0.03,
#                                                                max_depth=6,
#                                                                max_iter=300,
#                                                                random_state=42)),
#                                ('catboost',
#                                 <catboost.core.CatBoostClassifier object at 0x7e88d0fecc40>)],
#                    final_estimator=LogisticRegression(max_iter=1000,
#                                                       multi_class='ovr'))

# %%
y_val_pred = stack.predict(X_val)

# %%
from sklearn.metrics import f1_score

final_f1_score = f1_score(y_val, y_val_pred, average='weighted')
print("Final Weighted F1-Score:", final_f1_score)
# Out:
# Final Weighted F1-Score: 0.8271828797785613

# %%
test_preds = stack.predict(test)

# %%
test_preds_decoded = le_traffic.inverse_transform(test_preds)

submission = pd.DataFrame({"Id": test_ids, "traffic_label": test_preds_decoded})
submission.to_csv("submission.csv", index=False)

# %%
from IPython.display import FileLink
FileLink("submission.csv")
# Out:
# /kaggle/working/submission.csv

# %%
import pandas as pd

label_counts = pd.Series(test_preds_decoded).value_counts()

print(label_counts)
# Out:
# Normal            30069
# Generic           18421
# Exploits          13082
# Fuzzers           11072
# DoS                3420
# Reconnaissance     3049
# Analysis           1679
# Backdoor            907
# Shellcode           617
# Worms                16
# Name: count, dtype: int64
